# %%
# Title:  CBA: Classification Based on Association

# INSTALL AND LOAD PACKAGES ################################

# Install pacman if you don't have it (uncomment next line)
# install.packages("pacman")

# Install and/or load packages with pacman
pacman::p_load(  # Use p_load function from pacman
  arulesCBA,     # Classification Based on Association
  caret,         # Confusion matrix for predictions
  magrittr,      # Pipes
  pacman,        # Load/unload packages
  rio,           # Import/export data
  tidyverse      # So many reasons
)
# Out:
# also installing the dependencies ‘shape’, ‘discretization’, ‘glmnet’
# The downloaded binary packages are in
# 	/var/folders/rh/pfd6hrw52s35skb7d44l36nr0000gn/T//RtmpLHccwp/downloaded_packages
# arulesCBA installed

# %%
# LOAD AND PREPARE DATA ####################################

# Set random seed for reproducibility in processes like
# splitting the data. You can use any number.
set.seed(1)

# %%
# Import pre-processed penguin data
df <- import("../data/penguins.rds") %>%
  print()
# Out:
# # A tibble: 342 x 5
#    y      bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
#    <fct>           <dbl>         <dbl>             <int>       <int>
#  1 Adelie           39.1          18.7               181        3750
#  2 Adelie           39.5          17.4               186        3800
#  3 Adelie           40.3          18                 195        3250
#  4 Adelie           36.7          19.3               193        3450
#  5 Adelie           39.3          20.6               190        3650
#  6 Adelie           38.9          17.8               181        3625
#  7 Adelie           39.2          19.6               195        4675
#  8 Adelie           34.1          18.1               193        3475
#  9 Adelie           42            20.2               190        4250
# 10 Adelie           37.8          17.1               186        3300
# # … with 332 more rows

# %%
# Discretize data using the "Minimum Description Length
# Principle" (MDLP) algorithm and save to `df`; by naming
# the `Species` variable `y` (done earlier), it's easier to
# reuse code
df <- 
  discretizeDF.supervised(  # Function from `arulesCBA`
    y ~ .,                  # Species based on rest
    data = df,              # Data source
    method = "mdlp"         # Algorithm to use
  )

# %%
# Check the first few rows of data
df
# Out:
#     y         bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 2   Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 3   Adelie    [-Inf,42.3)    [17.4, Inf]   [192,206)
# 4   Adelie    [-Inf,42.3)    [17.4, Inf]   [192,206)
# 5   Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 6   Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 7   Adelie    [-Inf,42.3)    [17.4, Inf]   [192,206)
# 8   Adelie    [-Inf,42.3)    [17.4, Inf]   [192,206)
# 9   Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 10  Adelie    [-Inf,42.3)    [16.4,17.4)   [-Inf,192)
# 11  Adelie    [-Inf,42.3)    [16.4,17.4)   [-Inf,192)
# 12  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 13  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 14  Adelie    [-Inf,42.3)    [17.4, Inf]   [192,206)
# 15  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 16  Adelie    [-Inf,42.3)    [17.4, Inf]   [192,206)
# 17  Adelie    [42.3,46)      [17.4, Inf]   [192,206)
# 18  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 19  Adelie    [42.3,46)      [17.4, Inf]   [192,206)
# 20  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 21  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 22  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 23  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 24  Adelie    [-Inf,42.3)    [16.4,17.4)   [-Inf,192)
# 25  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 26  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 27  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 28  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 29  Adelie    [-Inf,42.3)    [17.4, Inf]   [-Inf,192)
# 30  Adelie    [-Inf,42.3)    [16.4,17.4)   [-Inf,192)
# ⋮   ⋮         ⋮              ⋮             ⋮
# 313 Chinstrap [46, Inf]      [16.4,17.4)   [-Inf,192)
# 314 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 315 Chinstrap [46, Inf]      [17.4, Inf]   [206, Inf]
# 316 Chinstrap [46, Inf]      [17.4, Inf]   [-Inf,192)
# 317 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 318 Chinstrap [42.3,46)      [16.4,17.4)   [192,206)
# 319 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 320 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 321 Chinstrap [46, Inf]      [17.4, Inf]   [-Inf,192)
# 322 Chinstrap [46, Inf]      [17.4, Inf]   [206, Inf]
# 323 Chinstrap [46, Inf]      [17.4, Inf]   [-Inf,192)
# 324 Chinstrap [46, Inf]      [16.4,17.4)   [192,206)
# 325 Chinstrap [46, Inf]      [16.4,17.4)   [192,206)
# 326 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 327 Chinstrap [42.3,46)      [16.4,17.4)   [192,206)
# 328 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 329 Chinstrap [42.3,46)      [16.4,17.4)   [-Inf,192)
# 330 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 331 Chinstrap [42.3,46)      [16.4,17.4)   [-Inf,192)
# 332 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 333 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 334 Chinstrap [42.3,46)      [17.4, Inf]   [192,206)
# 335 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 336 Chinstrap [46, Inf]      [16.4,17.4)   [-Inf,192)
# 337 Chinstrap [42.3,46)      [16.4,17.4)   [192,206)
# 338 Chinstrap [46, Inf]      [17.4, Inf]   [206, Inf]
# 339 Chinstrap [42.3,46)      [17.4, Inf]   [192,206)
# 340 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
# 341 Chinstrap [46, Inf]      [17.4, Inf]   [206, Inf]
# 342 Chinstrap [46, Inf]      [17.4, Inf]   [192,206)
#     body_mass_g
# 1   [-Inf,4.09e+03)
# 2   [-Inf,4.09e+03)
# 3   [-Inf,4.09e+03)
# 4   [-Inf,4.09e+03)
# 5   [-Inf,4.09e+03)
# 6   [-Inf,4.09e+03)
# 7   [4.32e+03,4.82e+03)
# 8   [-Inf,4.09e+03)
# 9   [4.09e+03,4.32e+03)
# 10  [-Inf,4.09e+03)
# 11  [-Inf,4.09e+03)
# 12  [-Inf,4.09e+03)
# 13  [-Inf,4.09e+03)
# 14  [4.32e+03,4.82e+03)
# 15  [-Inf,4.09e+03)
# 16  [-Inf,4.09e+03)
# 17  [4.32e+03,4.82e+03)
# 18  [-Inf,4.09e+03)
# 19  [4.09e+03,4.32e+03)
# 20  [-Inf,4.09e+03)
# 21  [-Inf,4.09e+03)
# 22  [-Inf,4.09e+03)
# 23  [-Inf,4.09e+03)
# 24  [-Inf,4.09e+03)
# 25  [-Inf,4.09e+03)
# 26  [-Inf,4.09e+03)
# 27  [-Inf,4.09e+03)
# 28  [-Inf,4.09e+03)
# 29  [-Inf,4.09e+03)
# 30  [-Inf,4.09e+03)
# ⋮   ⋮
# 313 [-Inf,4.09e+03)
# 314 [4.32e+03,4.82e+03)
# 315 [-Inf,4.09e+03)
# 316 [-Inf,4.09e+03)
# 317 [-Inf,4.09e+03)
# 318 [-Inf,4.09e+03)
# 319 [-Inf,4.09e+03)
# 320 [4.32e+03,4.82e+03)
# 321 [-Inf,4.09e+03)
# 322 [4.09e+03,4.32e+03)
# 323 [-Inf,4.09e+03)
# 324 [-Inf,4.09e+03)
# 325 [-Inf,4.09e+03)
# 326 [-Inf,4.09e+03)
# 327 [-Inf,4.09e+03)
# 328 [-Inf,4.09e+03)
# 329 [-Inf,4.09e+03)
# 330 [-Inf,4.09e+03)
# 331 [-Inf,4.09e+03)
# 332 [-Inf,4.09e+03)
# 333 [-Inf,4.09e+03)
# 334 [-Inf,4.09e+03)
# 335 [-Inf,4.09e+03)
# 336 [-Inf,4.09e+03)
# 337 [-Inf,4.09e+03)
# 338 [-Inf,4.09e+03)
# 339 [-Inf,4.09e+03)
# 340 [-Inf,4.09e+03)
# 341 [4.09e+03,4.32e+03)
# 342 [-Inf,4.09e+03)

# %%
# Split data into training (trn) and testing (tst) sets
df %<>% mutate(ID = row_number())  # Add row ID
trn <- df %>% sample_frac(.70)     # 70% in trn
tst <- df %>%                      # Start with df
  anti_join(trn, by = "ID") %>%    # Rest in tst
  select(-ID)                      # Remove id from tst
trn %<>% select(-ID)               # Remove id from trn

# %%
# MODEL DATA ###############################################

# Create a CBA model using `CBA` from `arulesCBA`
fit <- CBA(   # `fit` is a generic name for models
  y ~ .,      # Species based on all other variables
  data = trn  # Use training data
)

# %%
# Basic info on the model in `fit`
fit
# Out:
# CBA Classifier Object
# Class:
# Default Class: NA
# Number of rules: 10
# Classification method: first
# Description: CBA algorithm (Liu et al., 1998)

# %%
# Check the rules
options(digits = 2)  # Reset R session when done
inspect(rules(fit))  # Need a (very) wide Console window
# Out:
#      lhs                               rhs           support confidence coverage lift count size coveredTransactions totalErrors
# [1]  {bill_length_mm=[-Inf,42.3),
#       bill_depth_mm=[17.4, Inf]}    => {y=Adelie}       0.28       1.00     0.28  2.4    68    3                  68          81
# [2]  {bill_depth_mm=[-Inf,15.4)}    => {y=Gentoo}       0.26       1.00     0.26  2.7    63    2                  63          60
# [3]  {body_mass_g=[4.82e+03, Inf]}  => {y=Gentoo}       0.25       1.00     0.25  2.7    60    2                  27          33
# [4]  {bill_length_mm=[46, Inf],
#       bill_depth_mm=[17.4, Inf]}    => {y=Chinstrap}    0.14       1.00     0.14  5.0    34    3                  34          14
# [5]  {bill_length_mm=[46, Inf],
#       body_mass_g=[-Inf,4.09e+03)}  => {y=Chinstrap}    0.13       1.00     0.13  5.0    30    3                   4          10
# [6]  {bill_length_mm=[-Inf,42.3),
#       flipper_length_mm=[192,206)}  => {y=Adelie}       0.10       1.00     0.10  2.4    24    3                   4          10
# [7]  {bill_length_mm=[-Inf,42.3),
#       body_mass_g=[-Inf,4.09e+03)}  => {y=Adelie}       0.33       0.99     0.33  2.3    78    3                  21          10
# [8]  {bill_length_mm=[42.3,46),
#       flipper_length_mm=[206, Inf]} => {y=Gentoo}       0.10       0.96     0.10  2.5    24    3                   1          10
# [9]  {bill_depth_mm=[17.4, Inf],
#       flipper_length_mm=[-Inf,192)} => {y=Adelie}       0.21       0.89     0.23  2.1    50    3                   2           8
# [10] {}                             => {y=Chinstrap}    0.20       0.20       NA  1.0   239    1                  15           8

# %%
# Check accuracy of the model on the training data
confusionMatrix(      # Create a confusion matrix
  reference = trn$y,  # True values
  predict(            # Predicted values
    fit,              # Based on the training model
    newdata = trn     # Use the training data
  )
)
# Out:
# Confusion Matrix and Statistics
#
#            Reference
# Prediction  Adelie Chinstrap Gentoo
#   Adelie        94         1      0
#   Chinstrap      6        47      0
#   Gentoo         1         0     90
#
# Overall Statistics
#
#                Accuracy : 0.967
#                  95% CI : (0.935, 0.985)
#     No Information Rate : 0.423
#     P-Value [Acc > NIR] : <2e-16
#
#                   Kappa : 0.948
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: Adelie Class: Chinstrap Class: Gentoo
# Sensitivity                  0.931            0.979         1.000
# Specificity                  0.993            0.969         0.993
# Pos Pred Value               0.989            0.887         0.989
# Neg Pred Value               0.951            0.995         1.000
# Prevalence                   0.423            0.201         0.377
# Detection Rate               0.393            0.197         0.377
# Detection Prevalence         0.397            0.222         0.381
# Balanced Accuracy            0.962            0.974         0.997

# %%
# TEST MODEL ###############################################

# Check accuracy of the model on the testing data
confusionMatrix(      # Create a confusion matrix
  reference = tst$y,  # True values
  predict(            # Predicted values
    fit,              # Based on the training model
    newdata = tst     # Use the testing data
  )
)
# Out:
# Confusion Matrix and Statistics
#
#            Reference
# Prediction  Adelie Chinstrap Gentoo
#   Adelie        47         1      0
#   Chinstrap      3        19      0
#   Gentoo         0         0     33
#
# Overall Statistics
#
#                Accuracy : 0.961
#                  95% CI : (0.904, 0.989)
#     No Information Rate : 0.485
#     P-Value [Acc > NIR] : <2e-16
#
#                   Kappa : 0.938
#
#  Mcnemar's Test P-Value : NA
#
# Statistics by Class:
#
#                      Class: Adelie Class: Chinstrap Class: Gentoo
# Sensitivity                  0.940            0.950          1.00
# Specificity                  0.981            0.964          1.00
# Pos Pred Value               0.979            0.864          1.00
# Neg Pred Value               0.945            0.988          1.00
# Prevalence                   0.485            0.194          0.32
# Detection Rate               0.456            0.184          0.32
# Detection Prevalence         0.466            0.214          0.32
# Balanced Accuracy            0.961            0.957          1.00
