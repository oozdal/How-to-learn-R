# %%
# Title:  Sentiment Analysis: Binary Classification

# INSTALL AND LOAD PACKAGES ################################

# Install pacman if you don't have it (uncomment next line)
# install.packages("pacman")

# Install and/or load packages with pacman
pacman::p_load(  # Use p_load function from pacman
  gutenbergr,    # Import Project Gutenberg texts
  magrittr,      # Pipes
  pacman,        # Load/unload packages
  rio,           # Import/export data
  tidytext,      # Text functions
  tidyverse      # So many reasons 
)

# %%
# IMPORT DATA ##############################################

# Download "The Iliad" by Homer from Project Gutenberg. The
# `gutenberg_download` function can access books by ID,
# which you can get from the Gutenberg website,
# https://www.gutenberg.org. (The book's page is
# http://www.gutenberg.org/ebooks/6150)

# Import local file and save as tibble
df <- import("../data/Iliad.txt") %>% as_tibble()

# Look at the first few rows
df
# Out:
#       gutenberg_id
# 1     6150
# 2     6150
# 3     6150
# 4     6150
# 5     6150
# 6     6150
# 7     6150
# 8     6150
# 9     6150
# 10    6150
# 11    6150
# 12    6150
# 13    6150
# 14    6150
# 15    6150
# 16    6150
# 17    6150
# 18    6150
# 19    6150
# 20    6150
# 21    6150
# 22    6150
# 23    6150
# 24    6150
# 25    6150
# 26    6150
# 27    6150
# 28    6150
# 29    6150
# 30    6150
# ⋮     ⋮
# 19971 6150
# 19972 6150
# 19973 6150
# 19974 6150
# 19975 6150
# 19976 6150
# 19977 6150
# 19978 6150
# 19979 6150
# 19980 6150
# 19981 6150
# 19982 6150
# 19983 6150
# 19984 6150
# 19985 6150
# 19986 6150
# 19987 6150
# 19988 6150
# 19989 6150
# 19990 6150
# 19991 6150
# 19992 6150
# 19993 6150
# 19994 6150
# 19995 6150
# 19996 6150
# 19997 6150
# 19998 6150
# 19999 6150
# 20000 6150
#       text
# 1     The Iliad
# 2
# 3     by Homer
# 4
# 5     Rendered into English Blank verse by
# 6     Edward, Earl of Derby
# 7
# 8
# 9
# 10
# 11    Contents
# 12
# 13    PREFACE.
# 14    BOOK I.
# 15    BOOK II.
# 16    BOOK III.
# 17    BOOK IV.
# 18    BOOK V.
# 19    BOOK VI.
# 20    BOOK VII.
# 21    BOOK VIII.
# 22    BOOK IX.
# 23    BOOK X.
# 24    BOOK XI.
# 25    BOOK XII.
# 26    BOOK XIII.
# 27    BOOK XIV.
# 28    BOOK XV.
# 29    BOOK XVI.
# 30    BOOK XVII.
# ⋮     ⋮
# 19971 Virgil, who represents the same ladies [G. 4. 336] in attendance on
# 19972 Cyrene; and has not only reduced the list, but added some slight
# 19973 touches illustrating their occupations and private history: a liberty
# 19974 permissible to an imitator, but not to a translator.
# 19975
# 19976
# 19977 [6] L. 151. Chthizos, yesterday. But either the word must have a more
# 19978 extended signification than is usually given to it, or Homer must here
# 19979 have fallen into an error; for two complete nights and one day, that
# 19980 on which Patroclus met his death, had intervened since the visit of
# 19981 Ajax and Ulysses to the tent of Achilles. See also l. 215.
# 19982
# 19983
# 19984 [7] L. 547. The terms made use of in this line, and in 481, may appear
# 19985 somewhat coarse, as addressed by one Goddess to another: but I assure
# 19986 the English reader that in this passage especially I have greatly
# 19987 softened down the expression of the original; a literal translation of
# 19988 which, however forcible, would shock even the least fastidious critic.
# 19989 It must, indeed, be admitted that the mode in which “the white-armed
# 19990 Goddess” proceeds to execute her threat is hardly more dignified than
# 19991 the language, in which it is conveyed, is refined.
# 19992
# 19993
# 19994 [8] Line 737.—They being two, while I was only one. Such I believe to
# 19995 be the true interpretation of this passage, which, however, is one of
# 19996 admitted difficulty. According to our modern notions, it is not very
# 19997 evident what advantage two men in a car would have over one in
# 19998 another; nor what would be gained by the division of labour which
# 19999 assigned the reins to one and the whip to the other; but such, from
# 20000 line 740-741, appears to have been the view taken by Homer.

# %%
# PREPARE DATA #############################################

#text_df<-tokenize_words(as.character(df))

# Tokenize the data
df %<>%              # Overwrite data
  select(text)       # Keep text only
  
df %<>% unnest_tokens(     # Separate the text
  word,                    # Split text into words
  text                     # Save in text format
  )

df
# Out:
#        word
# 1      the
# 2      iliad
# 3      by
# 4      homer
# 5      rendered
# 6      into
# 7      english
# 8      blank
# 9      verse
# 10     by
# 11     edward
# 12     earl
# 13     of
# 14     derby
# 15     contents
# 16     preface
# 17     book
# 18     i
# 19     book
# 20     ii
# 21     book
# 22     iii
# 23     book
# 24     iv
# 25     book
# 26     v
# 27     book
# 28     vi
# 29     book
# 30     vii
# ⋮      ⋮
# 146325 division
# 146326 of
# 146327 labour
# 146328 which
# 146329 assigned
# 146330 the
# 146331 reins
# 146332 to
# 146333 one
# 146334 and
# 146335 the
# 146336 whip
# 146337 to
# 146338 the
# 146339 other
# 146340 but
# 146341 such
# 146342 from
# 146343 line
# 146344 740
# 146345 741
# 146346 appears
# 146347 to
# 146348 have
# 146349 been
# 146350 the
# 146351 view
# 146352 taken
# 146353 by
# 146354 homer

# %%
# See the tokens/words by frequency
df %>% count(word, sort = TRUE)
# Out:
#      word       n
# 1    the        9901
# 2    and        5543
# 3    of         3944
# 4    to         3558
# 5    his        2841
# 6    in         2408
# 7    he         2018
# 8    with       1947
# 9    from       1256
# 10   a          1246
# 11   by         1108
# 12   on         1097
# 13   but        1093
# 14   i          1031
# 15   for         932
# 16   their       905
# 17   all         882
# 18   as          877
# 19   son         867
# 20   my          822
# 21   him         811
# 22   they        772
# 23   thou        757
# 24   that        752
# 25   then        731
# 26   thus        731
# 27   thy         688
# 28   not         661
# 29   who         590
# 30   greeks      530
# ⋮    ⋮          ⋮
# 9303 working    1
# 9304 workman    1
# 9305 worm       1
# 9306 worship    1
# 9307 worshipp’d 1
# 9308 would’st   1
# 9309 wounding   1
# 9310 wrangling  1
# 9311 wrench     1
# 9312 wrenching  1
# 9313 wrestlers  1
# 9314 wrests     1
# 9315 wretches   1
# 9316 wriggling  1
# 9317 wrings     1
# 9318 wrinkled   1
# 9319 wrinkles   1
# 9320 yearning   1
# 9321 yell’d     1
# 9322 yells      1
# 9323 yes        1
# 9324 yestermorn 1
# 9325 yokeband   1
# 9326 yokefellow 1
# 9327 youth’s    1
# 9328 zacynthus  1
# 9329 zealous    1
# 9330 zeleia     1
# 9331 zeus       1
# 9332 zone       1

# %%
# Remove "stop words" like "the," "to," "a," and so on.
df %<>% anti_join(stop_words)
# Out:
# Joining, by = "word"

# %%
# See the revised tokens/words by frequency
df %>% count(word, sort = TRUE)
# Out:
#      word       n
# 1    son        867
# 2    thou       757
# 3    thy        688
# 4    greeks     530
# 5    achilles   445
# 6    hector     429
# 7    ships      422
# 8    thee       421
# 9    jove       392
# 10   hand       387
# 11   spear      351
# 12   trojans    343
# 13   o’er       298
# 14   gods       272
# 15   fight      268
# 16   troy       250
# 17   arms       248
# 18   death      236
# 19   ye         236
# 20   words      234
# 21   stood      225
# 22   war        213
# 23   hath       205
# 24   heav’n     202
# 25   battle     200
# 26   car        189
# 27   patroclus  185
# 28   spoke      172
# 29   horses     170
# 30   ajax       168
# ⋮    ⋮          ⋮
# 8843 woodmen    1
# 8844 woody      1
# 8845 workman    1
# 8846 worm       1
# 8847 worship    1
# 8848 worshipp’d 1
# 8849 would’st   1
# 8850 wounding   1
# 8851 wrangling  1
# 8852 wrench     1
# 8853 wrenching  1
# 8854 wrestlers  1
# 8855 wrests     1
# 8856 wretches   1
# 8857 wriggling  1
# 8858 wrings     1
# 8859 wrinkled   1
# 8860 wrinkles   1
# 8861 yearning   1
# 8862 yell’d     1
# 8863 yells      1
# 8864 yestermorn 1
# 8865 yokeband   1
# 8866 yokefellow 1
# 8867 youth’s    1
# 8868 zacynthus  1
# 8869 zealous    1
# 8870 zeleia     1
# 8871 zeus       1
# 8872 zone       1

# %%
# CATEGORIZE SENTIMENTS ####################################

# Find positive and negative words with the "bing" lexicon
df %>%
  inner_join(                # Match words with sentiments
    get_sentiments("bing")   # Use "bing" sentiment library
  )
# Out:
# Joining, by = "word"
#       word         sentiment
# 1     modern       positive
# 2     success      positive
# 3     sufficiently positive
# 4     encourage    positive
# 5     urgent       negative
# 6     regret       negative
# 7     sincere      positive
# 8     diffidence   negative
# 9     success      positive
# 10    ordeal       negative
# 11    criticism    negative
# 12    forbid       negative
# 13    fear         negative
# 14    decline      negative
# 15    enjoy        positive
# 16    prefer       positive
# 17    harmonious   positive
# 18    polished     positive
# 19    happy        positive
# 20    admirable    positive
# 21    lost         negative
# 22    succeeded    positive
# 23    faint        negative
# 24    delighted    positive
# 25    partisans    negative
# 26    pestilent    negative
# 27    heresy       negative
# 28    repugnant    negative
# 29    genius       positive
# 30    violation    negative
# ⋮     ⋮            ⋮
# 10562 anger        negative
# 10563 champion     positive
# 10564 paradise     positive
# 10565 lost         negative
# 10566 fiend        negative
# 10567 afford       positive
# 10568 accurate     positive
# 10569 faster       positive
# 10570 outstrip     positive
# 10571 slower       negative
# 10572 oversight    negative
# 10573 killed       negative
# 10574 death        negative
# 10575 liberty      positive
# 10576 permissible  positive
# 10577 fallen       negative
# 10578 error        negative
# 10579 death        negative
# 10580 coarse       negative
# 10581 assure       positive
# 10582 shock        negative
# 10583 fastidious   negative
# 10584 critic       negative
# 10585 threat       negative
# 10586 dignified    positive
# 10587 refined      positive
# 10588 difficulty   negative
# 10589 modern       positive
# 10590 advantage    positive
# 10591 gained       positive

# %%
# Sort sentiment words by frequency
df %>%
  inner_join(                # Match words with sentiments
    get_sentiments("bing")   # Use "bing" sentiment library
  ) %>% 
  count(word, sort = TRUE)
# Out:
# Joining, by = "word"
#      word           n
# 1    death          236
# 2    brave          165
# 3    fell           164
# 4    mighty         163
# 5    valiant        160
# 6    bore           152
# 7    fair           152
# 8    godlike        144
# 9    noble          141
# 10   struck         126
# 11   swift          124
# 12   led            120
# 13   loud           115
# 14   haste          108
# 15   dead           106
# 16   fear           106
# 17   grief          100
# 18   wrath           96
# 19   warlike         92
# 20   fall            91
# 21   courage         88
# 22   dark            88
# 23   wrought         88
# 24   dust            77
# 25   golden          75
# 26   brazen          74
# 27   cloud           74
# 28   fierce          72
# 29   vain            70
# 30   anger           68
# ⋮    ⋮              ⋮
# 1240 unkindly       1
# 1241 unnerve        1
# 1242 unsuccessfully 1
# 1243 unsuspecting   1
# 1244 unwelcome      1
# 1245 unwisely       1
# 1246 uphold         1
# 1247 uplifting      1
# 1248 venomous       1
# 1249 vilify         1
# 1250 violate        1
# 1251 violation      1
# 1252 violent        1
# 1253 vouchsafe      1
# 1254 warp           1
# 1255 wasteful       1
# 1256 weaker         1
# 1257 weakness       1
# 1258 weariness      1
# 1259 weed           1
# 1260 whining        1
# 1261 whips          1
# 1262 wholesome      1
# 1263 wicked         1
# 1264 wins           1
# 1265 wonderful      1
# 1266 wonders        1
# 1267 wrinkled       1
# 1268 wrinkles       1
# 1269 zealous        1

# %%
# Summarize the number (and proportion) of sentiments
df %>%
  inner_join(                # Match words with sentiments
    get_sentiments("bing")   # Use "bing" sentiment library
  ) %>% 
  group_by(sentiment) %>%    # Group sentiments
  summarize(n = n()) %>%     # Count number of words
  mutate(prop = n / sum(n))  # Get proportions of total
# Out:
# Joining, by = "word"
#   sentiment n    prop
# 1 negative  6385 0.6028704
# 2 positive  4206 0.3971296
