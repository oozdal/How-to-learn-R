# %%
# Title:  Solution: Sentiment Scoring

# INSTALL AND LOAD PACKAGES ################################

# Install pacman if you don't have it (uncomment next line)
# install.packages("pacman")

# Install and/or load packages with pacman
pacman::p_load(  # Use p_load function from pacman
  gutenbergr,    # Import Project Gutenberg texts
  magrittr,      # Pipes
  pacman,        # Load/unload packages
  rio,           # Import/export data
  tidytext,      # Text functions
  tidyverse      # So many reasons
)

# %%
# IMPORT DATA ##############################################

# Download "Little Women" by Louisa May Alcott from Project
# Gutenberg. The `gutenberg_download` function can access
# books by ID, which you can get from the Gutenberg website,
# https://www.gutenberg.org. (The book's page is
# http://www.gutenberg.org/ebooks/514.)
# df <- gutenberg_download(  # Save to `df`
#   514,                     # Book ID
#   strip = TRUE             # Remove headers and footers
# )

# Import local file
df <- import("../data/LittleWomen.txt") %>% as_tibble()

# See first few lines
df
# Out:
#       gutenberg_id
# 1     514
# 2     514
# 3     514
# 4     514
# 5     514
# 6     514
# 7     514
# 8     514
# 9     514
# 10    514
# 11    514
# 12    514
# 13    514
# 14    514
# 15    514
# 16    514
# 17    514
# 18    514
# 19    514
# 20    514
# 21    514
# 22    514
# 23    514
# 24    514
# 25    514
# 26    514
# 27    514
# 28    514
# 29    514
# 30    514
# ⋮     ⋮
# 20599 514
# 20600 514
# 20601 514
# 20602 514
# 20603 514
# 20604 514
# 20605 514
# 20606 514
# 20607 514
# 20608 514
# 20609 514
# 20610 514
# 20611 514
# 20612 514
# 20613 514
# 20614 514
# 20615 514
# 20616 514
# 20617 514
# 20618 514
# 20619 514
# 20620 514
# 20621 514
# 20622 514
# 20623 514
# 20624 514
# 20625 514
# 20626 514
# 20627 514
# 20628 514
#       text
# 1     LITTLE WOMEN
# 2
# 3
# 4     by
# 5
# 6     Louisa May Alcott
# 7
# 8
# 9
# 10
# 11    CONTENTS
# 12
# 13
# 14    PART 1
# 15
# 16    ONE  PLAYING PILGRIMS
# 17    TWO  A MERRY CHRISTMAS
# 18    THREE  THE LAURENCE BOY
# 19    FOUR  BURDENS
# 20    FIVE  BEING NEIGHBORLY
# 21    SIX  BETH FINDS THE PALACE BEAUTIFUL
# 22    SEVEN  AMY'S VALLEY OF HUMILIATION
# 23    EIGHT  JO MEETS APOLLYON
# 24    NINE  MEG GOES TO VANITY FAIR
# 25    TEN  THE P.C. AND P.O.
# 26    ELEVEN  EXPERIMENTS
# 27    TWELVE  CAMP LAURENCE
# 28    THIRTEEN  CASTLES IN THE AIR
# 29    FOURTEEN  SECRETS
# 30    FIFTEEN  A TELEGRAM
# ⋮     ⋮
# 20599 happier than I deserve,"" added Jo, glancing from her good husband to
# 20600 her chubby children, tumbling on the grass beside her.  ""Fritz is
# 20601 getting gray and stout.  I'm growing as thin as a shadow, and am
# 20602 thirty.  We never shall be rich, and Plumfield may burn up any night,
# 20603 for that incorrigible Tommy Bangs will smoke sweet-fern cigars under
# 20604 the bed-clothes, though he's set himself afire three times already.
# 20605 But in spite of these unromantic facts, I have nothing to complain of,
# 20606 and never was so jolly in my life.  Excuse the remark, but living among
# 20607 boys, I can't help using their expressions now and then.""
# 20608
# 20609 ""Yes, Jo, I think your harvest will be a good one,"" began Mrs. March,
# 20610 frightening away a big black cricket that was staring Teddy out of
# 20611 countenance.
# 20612
# 20613 ""Not half so good as yours, Mother.  Here it is, and we never can thank
# 20614 you enough for the patient sowing and reaping you have done,"" cried Jo,
# 20615 with the loving impetuosity which she never would outgrow.
# 20616
# 20617 ""I hope there will be more wheat and fewer tares every year,"" said Amy
# 20618 softly.
# 20619
# 20620 ""A large sheaf, but I know there's room in your heart for it, Marmee
# 20621 dear,"" added Meg's tender voice.
# 20622
# 20623 Touched to the heart, Mrs. March could only stretch out her arms, as if
# 20624 to gather children and grandchildren to herself, and say, with face and
# 20625 voice full of motherly love, gratitude, and humility...
# 20626
# 20627 ""Oh, my girls, however long you may live, I never can wish you a
# 20628 greater happiness than this!""

# %%
# PREPARE DATA #############################################

# Add line numbers to divide text into sections
df %<>% 
  mutate(line = row_number()) %>%
  select(-gutenberg_id) %>%        # Remove book ID number
  print()
# Out:
# # A tibble: 20,628 x 2
#    text                 line
#    <chr>               <int>
#  1 "LITTLE WOMEN"          1
#  2 ""                      2
#  3 ""                      3
#  4 "by"                    4
#  5 ""                      5
#  6 "Louisa May Alcott"     6
#  7 ""                      7
#  8 ""                      8
#  9 ""                      9
# 10 ""                     10
# # … with 20,618 more rows

# %%
# Tokenize the data
words <- df %>%
  unnest_tokens(word, text) %>%  # Break lines into words
  print()
# Out:
# # A tibble: 186,827 x 2
#     line word
#    <int> <chr>
#  1     1 little
#  2     1 women
#  3     4 by
#  4     6 louisa
#  5     6 may
#  6     6 alcott
#  7    11 contents
#  8    14 part
#  9    14 1
# 10    16 one
# # … with 186,817 more rows

# %%
# SENTIMENT FREQUENCIES ####################################

# Calculate and print score frequencies. Sentiment scores
# come from the AFINN lexicon, which scores the sentiment of
# words on a scale of -5 (most negative) to +5 (most
# positive)
score_freq <- words %>%
  inner_join(get_sentiments("afinn")) %>%
  group_by(value) %>% # Grouping by sentiment scores
  summarize(n = n()) %>%
  print()
# Out:
# Joining, by = "word"
# # A tibble: 9 x 2
#   value     n
# * <dbl> <int>
# 1    -5     2
# 2    -3   686
# 3    -2  2785
# 4    -1  1761
# 5     1  2136
# 6     2  4408
# 7     3  2613
# 8     4   187
# 9     5     3

# %%
# Graph score frequencies (change scale to -5, +5)
score_freq %>% 
  ggplot(aes(value, n)) +
  geom_bar(stat = "identity") +
  scale_x_continuous(breaks = seq(-5, 5, by = 1)) +
  ggtitle("Little Women: Sentiment Scores by Words") +
  xlab("Sentiment Score") +
  ylab("Frequency of Words")
# Out:
# plot without title

# %%
# SENTIMENT ARC ############################################

# Divide the text into sections of 100 lines and calculate a
# sentiment score for each section
score_arc <- words %>% 
  inner_join(get_sentiments("afinn")) %>%  # Use afinn
  group_by(section = line %/% 100) %>%     # Divide text
  summarize(score = mean(value)) %>%       # Section scores
  print()
# Out:
# Joining, by = "word"
# # A tibble: 207 x 2
#    section  score
#  *   <dbl>  <dbl>
#  1       0 0.0385
#  2       1 0.323
#  3       2 0.724
#  4       3 0.613
#  5       4 0.675
#  6       5 1.12
#  7       6 0.366
#  8       7 1.29
#  9       8 0.548
# 10       9 1.04
# # … with 197 more rows

# %%
# Plot scores by section to view narrative arc
score_arc %>% 
  ggplot(aes(section, score)) +
  geom_hline(yintercept = 0, col = "red") +
  geom_line(col = "gray") +
  geom_smooth(method = loess, col = "gray40") +  
  ggtitle("Little Women: Mean Sentiment Score by Section") +
  ylab("Mean Sentiment Score") +
  xlab("Section of 100 Lines")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title
