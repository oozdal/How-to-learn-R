# %%
# Title:  Visualizing Word Pairs

# INSTALL AND LOAD PACKAGES ################################

# Install pacman if you don't have it (uncomment next line)
# install.packages("pacman")

# Install and/or load packages with pacman
pacman::p_load(  # Use p_load function from pacman
  ggraph,        # Visualize network graphs
  gutenbergr,    # Import Project Gutenberg texts
  igraph,        # Network graph functions
  magrittr,      # Pipes
  pacman,        # Load/unload packages
  rio,           # Import/export data
  tidytext,      # Text functions
  tidyverse      # So many reasons
)

# Set random seed for reproducibility in processes like
# splitting the data
set.seed(1)  # You can use any number here
# Out:
# also installing the dependencies ‘tweenr’, ‘polyclip’, ‘ggforce’, ‘tidygraph’, ‘graphlayouts’
#   There is a binary version available but the source version is later:
#        binary source needs_compilation
# tweenr  1.0.1  1.0.2              TRUE
#
#
# The downloaded binary packages are in
# 	/var/folders/rh/pfd6hrw52s35skb7d44l36nr0000gn/T//RtmpUMD3Pf/downloaded_packages
# installing the source package ‘tweenr’
#
#
#
# ggraph installed

# %%
# IMPORT DATA ##############################################

# Download "The Iliad" by Homer from Project Gutenberg. The
# `gutenberg_download` function can access books by ID,
# which you can get from the Gutenberg website,
# https://www.gutenberg.org. (The book's page is
# http://www.gutenberg.org/ebooks/6150.)

# Import local file
df <- import("../data/Iliad.txt") %>% as_tibble()

# Look at the first few rows
df
# Out:
#       gutenberg_id
# 1     6150
# 2     6150
# 3     6150
# 4     6150
# 5     6150
# 6     6150
# 7     6150
# 8     6150
# 9     6150
# 10    6150
# 11    6150
# 12    6150
# 13    6150
# 14    6150
# 15    6150
# 16    6150
# 17    6150
# 18    6150
# 19    6150
# 20    6150
# 21    6150
# 22    6150
# 23    6150
# 24    6150
# 25    6150
# 26    6150
# 27    6150
# 28    6150
# 29    6150
# 30    6150
# ⋮     ⋮
# 19971 6150
# 19972 6150
# 19973 6150
# 19974 6150
# 19975 6150
# 19976 6150
# 19977 6150
# 19978 6150
# 19979 6150
# 19980 6150
# 19981 6150
# 19982 6150
# 19983 6150
# 19984 6150
# 19985 6150
# 19986 6150
# 19987 6150
# 19988 6150
# 19989 6150
# 19990 6150
# 19991 6150
# 19992 6150
# 19993 6150
# 19994 6150
# 19995 6150
# 19996 6150
# 19997 6150
# 19998 6150
# 19999 6150
# 20000 6150
#       text
# 1     The Iliad
# 2
# 3     by Homer
# 4
# 5     Rendered into English Blank verse by
# 6     Edward, Earl of Derby
# 7
# 8
# 9
# 10
# 11    Contents
# 12
# 13    PREFACE.
# 14    BOOK I.
# 15    BOOK II.
# 16    BOOK III.
# 17    BOOK IV.
# 18    BOOK V.
# 19    BOOK VI.
# 20    BOOK VII.
# 21    BOOK VIII.
# 22    BOOK IX.
# 23    BOOK X.
# 24    BOOK XI.
# 25    BOOK XII.
# 26    BOOK XIII.
# 27    BOOK XIV.
# 28    BOOK XV.
# 29    BOOK XVI.
# 30    BOOK XVII.
# ⋮     ⋮
# 19971 Virgil, who represents the same ladies [G. 4. 336] in attendance on
# 19972 Cyrene; and has not only reduced the list, but added some slight
# 19973 touches illustrating their occupations and private history: a liberty
# 19974 permissible to an imitator, but not to a translator.
# 19975
# 19976
# 19977 [6] L. 151. Chthizos, yesterday. But either the word must have a more
# 19978 extended signification than is usually given to it, or Homer must here
# 19979 have fallen into an error; for two complete nights and one day, that
# 19980 on which Patroclus met his death, had intervened since the visit of
# 19981 Ajax and Ulysses to the tent of Achilles. See also l. 215.
# 19982
# 19983
# 19984 [7] L. 547. The terms made use of in this line, and in 481, may appear
# 19985 somewhat coarse, as addressed by one Goddess to another: but I assure
# 19986 the English reader that in this passage especially I have greatly
# 19987 softened down the expression of the original; a literal translation of
# 19988 which, however forcible, would shock even the least fastidious critic.
# 19989 It must, indeed, be admitted that the mode in which “the white-armed
# 19990 Goddess” proceeds to execute her threat is hardly more dignified than
# 19991 the language, in which it is conveyed, is refined.
# 19992
# 19993
# 19994 [8] Line 737.—They being two, while I was only one. Such I believe to
# 19995 be the true interpretation of this passage, which, however, is one of
# 19996 admitted difficulty. According to our modern notions, it is not very
# 19997 evident what advantage two men in a car would have over one in
# 19998 another; nor what would be gained by the division of labour which
# 19999 assigned the reins to one and the whip to the other; but such, from
# 20000 line 740-741, appears to have been the view taken by Homer.

# %%
# PREPARE DATA #############################################

#Tokenize the data
df %<>%                # Overwrite data
  unnest_tokens(       # Separate the text
    wordpairs,         # Save data in variable `wordpairs`
    text,              # Save in text format
    token = "ngrams",  # Split into multiple-word "ngrams"
    n = 2              # Two words at a time
  )

# %%
# See the tokens/words by frequency
df %>% count(wordpairs, sort = TRUE)
# Out:
#       wordpairs          n
# 1     NA                 1402
# 2     to the              525
# 3     in the              450
# 4     of the              448
# 5     from the            443
# 6     the greeks          330
# 7     on the              308
# 8     son of              279
# 9     all the             223
# 10    and the             218
# 11    by the              212
# 12    the ships           212
# 13    the trojans         211
# 14    he said             199
# 15    through the         189
# 16    to whom             170
# 17    and with            168
# 18    in his              159
# 19    said and            153
# 20    of troy             152
# 21    of all              145
# 22    and in              142
# 23    and to              139
# 24    of greece           136
# 25    the gods            135
# 26    with the            132
# 27    to his              131
# 28    for the             130
# 29    the son             128
# 30    upon the            122
# ⋮     ⋮                  ⋮
# 61284 youths contend     1
# 61285 youths he          1
# 61286 youths in          1
# 61287 youths no          1
# 61288 youths nor         1
# 61289 youths pursued     1
# 61290 youths th          1
# 61291 youths the         1
# 61292 youths whirl’d     1
# 61293 youths whose       1
# 61294 zacynthus and      1
# 61295 zeal and           1
# 61296 zeal he            1
# 61297 zeal of            1
# 61298 zeal prepar’d      1
# 61299 zeal preparing     1
# 61300 zeal redoubled     1
# 61301 zeal the           1
# 61302 zeal they          1
# 61303 zeal unflagging    1
# 61304 zealous heretofore 1
# 61305 zeleia dwelt       1
# 61306 zephyr and         1
# 61307 zephyr bore        1
# 61308 zephyr from        1
# 61309 zephyr’s breath    1
# 61310 zephyr’s breeze    1
# 61311 zephyrus and       1
# 61312 zeus or            1
# 61313 zone from          1

# %%
# Split word pairs into two variables, which is necessary
# for network graphs.
df %<>%
  separate(
    wordpairs, 
    c("word1", "word2"), 
    sep = " "
  ) %>%
  select(-gutenberg_id) %>%  # Remove book ID number
  print()
# Out:
# # A tibble: 129,118 x 2
#    word1    word2
#    <chr>    <chr>
#  1 the      iliad
#  2 NA       NA
#  3 by       homer
#  4 NA       NA
#  5 rendered into
#  6 into     english
#  7 english  blank
#  8 blank    verse
#  9 verse    by
# 10 edward   earl
# # … with 129,108 more rows

# %%
# Remove word pairs that have stop words. Because there are
# now two words, it doesn't work to use the `anti_join`
# function used previously. Instead, the cases are filtered
# out if either word contains a stop word. This reduces the
# total number of observations from 146,318 to 28,019, an
# 81% reduction.
df %<>%
  filter(!word1 %in% stop_words$word) %>%
  filter(!word2 %in% stop_words$word) %>%
  print()
# Out:
# # A tibble: 25,803 x 2
#    word1   word2
#    <chr>   <chr>
#  1 NA      NA
#  2 NA      NA
#  3 english blank
#  4 blank   verse
#  5 edward  earl
#  6 NA      NA
#  7 NA      NA
#  8 NA      NA
#  9 NA      NA
# 10 NA      NA
# # … with 25,793 more rows

# %%
# Save sorted counts
df %<>% 
  count(
    word1, 
    word2, 
    sort = TRUE
  ) %>%
  print()
# Out:
# # A tibble: 16,793 x 3
#    word1    word2     n
#    <chr>    <chr> <int>
#  1 NA       NA     1402
#  2 peleus   son      51
#  3 saturn’s son      43
#  4 atreus   son      42
#  5 noble    son      41
#  6 thou     art      39
#  7 achilles swift    38
#  8 battle   field    38
#  9 glancing helm     37
# 10 immortal gods     36
# # … with 16,783 more rows

# %%
# Pair frequencies
df %>%
  group_by(n) %>%
  summarize(f = n()) %>%  # Count number of words
  mutate(p = n / sum(n))  # Get proportions of total
# Out:
#    n    f     p
# 1     1 13805 0.0004424779
# 2     2  1733 0.0008849558
# 3     3   539 0.0013274336
# 4     4   225 0.0017699115
# 5     5   132 0.0022123894
# 6     6    98 0.0026548673
# 7     7    61 0.0030973451
# 8     8    32 0.0035398230
# 9     9    28 0.0039823009
# 10   10    24 0.0044247788
# 11   11    15 0.0048672566
# 12   12    19 0.0053097345
# 13   13    12 0.0057522124
# 14   14     4 0.0061946903
# 15   15     2 0.0066371681
# 16   16     8 0.0070796460
# 17   17     5 0.0075221239
# 18   18     4 0.0079646018
# 19   19     3 0.0084070796
# 20   20     6 0.0088495575
# 21   21     2 0.0092920354
# 22   22     5 0.0097345133
# 23   23     2 0.0101769912
# 24   24     2 0.0106194690
# 25   25     5 0.0110619469
# 26   26     2 0.0115044248
# 27   27     2 0.0119469027
# 28   28     1 0.0123893805
# 29   29     2 0.0128318584
# 30   31     1 0.0137168142
# 31   32     1 0.0141592920
# 32   33     2 0.0146017699
# 33   36     2 0.0159292035
# 34   37     1 0.0163716814
# 35   38     2 0.0168141593
# 36   39     1 0.0172566372
# 37   41     1 0.0181415929
# 38   42     1 0.0185840708
# 39   43     1 0.0190265487
# 40   51     1 0.0225663717
# 41 1402     1 0.6203539823

# %%
# VISUALIZE DATA ###########################################

# See graph data
df %>%
  filter(n > 12) %>%           # Use observations w/n > 12
  graph_from_data_frame()      # Print the data in Console
# Out:
# Warning message in graph_from_data_frame(.):
# “In `d' `NA' elements were replaced with string "NA"”
# IGRAPH f767274 DN-- 112 82 --
# + attr: name (v/c), n (e/n)
# + edges from f767274 (vertex names):
#  [1] NA       ->NA        peleus   ->son       saturn’s ->son
#  [4] atreus   ->son       noble    ->son       thou     ->art
#  [7] achilles ->swift     battle   ->field     glancing ->helm
# [10] immortal ->gods      valiant  ->diomed    godlike  ->son
# [13] thou     ->hast      agamemnon->king      grecian  ->ships
# [16] bearing  ->jove      fair     ->hair’d    blue     ->ey’d
# [19] aegis    ->bearing   warlike  ->menelaus  brass    ->clad
# [22] white    ->arm’d     hast     ->thou      monarch  ->agamemnon
# + ... omitted several edges

# %%
# Visualize graph data (takes a moment)
df %>%
  filter(n > 12) %>%           # Use observations w/n > 12
  graph_from_data_frame() %>%  # Draw graph from `df`
  ggraph(layout = "fr") +      # Select "fr" layout
  geom_edge_link() +           # Graph the links 
  geom_node_point() +          # Graph the nodes
  geom_node_text(              # Add labels to nodes
    aes(label = name),         # Label each node by name
    nudge_x = .5,              # Move label slightly right
    nudge_y = .5               # Move label slightly up
  )
# Out:
# Warning message in graph_from_data_frame(.):
# “In `d' `NA' elements were replaced with string "NA"”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'saturn’s' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'saturn’s' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'saturn’s' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'pond’rous' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'pond’rous' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'pond’rous' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'heav’n' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'heav’n' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'heav’n' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'glitt’ring' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'glitt’ring' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'glitt’ring' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'greav’d' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'greav’d' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'greav’d' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'priam’s' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'priam’s' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'priam’s' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'bull’s' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'bull’s' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'bull’s' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'hair’d' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'hair’d' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'hair’d' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'ribb’d' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'ribb’d' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'ribb’d' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'call’d' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'call’d' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'call’d' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'ey’d' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'ey’d' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'ey’d' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'arm’d' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'arm’d' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'arm’d' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'address’d' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'address’d' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'address’d' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'stain’d' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'stain’d' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'stain’d' in 'mbcsToSbcs': dot substituted for <99>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'know’st' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'know’st' in 'mbcsToSbcs': dot substituted for <80>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'know’st' in 'mbcsToSbcs': dot substituted for <99>”
# plot without title
