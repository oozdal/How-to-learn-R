# %%
# Describe() gives you more detail than summary()

# INSTALL AND LOAD PACKAGES ################################

library(datasets)  # Load base packages manually

# Installs pacman ("package manager") if needed
if (!require("pacman")) install.packages("pacman")

# Use pacman to load add-on packages as desired
pacman::p_load(pacman, psych)
# Out:
# Loading required package: pacman
#
# also installing the dependencies ‘tmvnsim’, ‘mnormt’
# The downloaded binary packages are in
# 	/var/folders/rh/pfd6hrw52s35skb7d44l36nr0000gn/T//RtmpX1WJ8u/downloaded_packages
# psych installed

# %%
library(datasets) # Loading data
head(iris) # First few lines of the iris dataframe
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
# Load psych package (download if needed)
p_load(psych)

# %%
# Get info on package
p_help(psych, web=F)   # Opens help in Viewer
# Out:
# Documentation for package ‘psych’
#
#
# 		Information on package ‘psych’
#
# Description:
#
# Package:            psych
# Version:            2.0.12
# Date:               2020-12-14
# Title:              Procedures for Psychological, Psychometric, and
#                     Personality Research
# Authors@R:          person("William", "Revelle", role =c("aut","cre"),
#                     email="revelle@northwestern.edu", comment=c(ORCID =
#                     "0000-0003-4880-9610") )
# Description:        A general purpose toolbox for personality,
#                     psychometric theory and experimental psychology.
#                     Functions are primarily for multivariate analysis
#                     and scale construction using factor analysis,
#                     principal component analysis, cluster analysis and
#                     reliability analysis, although others provide basic
#                     descriptive statistics. Item Response Theory is
# ...

# %%
# Describe()

#For quantitative variables only

describe(iris$Sepal.Length) #One quantitative variable
# Out:
#    vars n   mean     sd        median trimmed  mad     min max range skew
# X1 1    150 5.843333 0.8280661 5.8    5.808333 1.03782 4.3 7.9 3.6   0.3086407
#    kurtosis   se
# X1 -0.6058125 0.06761132

# %%
describe(iris) #Entire data frame
# Out:
#              vars n   mean     sd        median trimmed  mad     min max range
# Sepal.Length 1    150 5.843333 0.8280661 5.80   5.808333 1.03782 4.3 7.9 3.6
# Sepal.Width  2    150 3.057333 0.4358663 3.00   3.043333 0.44478 2.0 4.4 2.4
# Petal.Length 3    150 3.758000 1.7652982 4.35   3.760000 1.85325 1.0 6.9 5.9
# Petal.Width  4    150 1.199333 0.7622377 1.30   1.184167 1.03782 0.1 2.5 2.4
# Species*     5    150 2.000000 0.8192319 2.00   2.000000 1.48260 1.0 3.0 2.0
#              skew       kurtosis   se
# Sepal.Length  0.3086407 -0.6058125 0.06761132
# Sepal.Width   0.3126147  0.1387047 0.03558833
# Petal.Length -0.2694109 -1.4168574 0.14413600
# Petal.Width  -0.1009166 -1.3581792 0.06223645
# Species*      0.0000000 -1.5199333 0.06689001
